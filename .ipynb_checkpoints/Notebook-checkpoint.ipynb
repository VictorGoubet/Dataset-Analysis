# %% [markdown]
# # <center>Python for data analysis</center>
# ## <center>Final project | SkillCraft</center>
#
# ------
#
# SkillCraft is a dataset composed of a lot of features of over three thousand players playing at StarCraft 2 from bronze to professionnal gamers. In ower study we will try to predict the league index of a player concidering all his others features. Thus, it is a classification problem.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
from sklearn.model_selection import train_test_split
import numpy as np
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier

# %matplotlib inline

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## First step

# %% [markdown]
# ### Import data

# %%
dataset = pd.read_csv("SkillCraft1_Dataset.csv", index_col="GameID")
dataset.sort_index(inplace=True)
dataset.head()
# Out:
#         LeagueIndex Age HoursPerWeek TotalHours       APM  SelectByHotkeys  \
# GameID
# 52                5  27           10       3000  143.7180         0.003515
# 55                5  23           10       5000  129.2322         0.003304
# 56                4  30           10        200   69.9612         0.001101
# 57                3  19           20        400  107.6016         0.001034
# 58                3  32           10        500  122.8908         0.001136
#
#         AssignToHotkeys  UniqueHotkeys  MinimapAttacks  MinimapRightClicks  \
# GameID
# 52             0.000220              7        0.000110            0.000392
# 55             0.000259              4        0.000294            0.000432
# 56             0.000336              4        0.000294            0.000461
# 57             0.000213              1        0.000053            0.000543
# 58             0.000327              2        0.000000            0.001329
#
#         NumberOfPACs  GapBetweenPACs  ActionLatency  ActionsInPAC  \
# GameID
# 52          0.004849         32.6677        40.8673        4.7508
# 55          0.004307         32.9194        42.3454        4.8434
# 56          0.002926         44.6475        75.3548        4.0430
# 57          0.003783         29.2203        53.7352        4.9155
# 58          0.002368         22.6885        62.0813        9.3740
#
#         TotalMapExplored  WorkersMade  UniqueUnitsMade  ComplexUnitsMade  \
# GameID
# 52                    28     0.001397                6               0.0
# 55                    22     0.001194                5               0.0
# 56                    22     0.000745                6               0.0
# 57                    19     0.000426                7               0.0
# 58                    15     0.001174                4               0.0
#
#         ComplexAbilitiesUsed
# GameID
# 52                  0.000000
# 55                  0.000208
# 56                  0.000189
# 57                  0.000384
# 58                  0.000019

# %% [markdown]
# ### Have a look on the types of the columns

# %%
dataset.dtypes
# Out:
# LeagueIndex               int64
# Age                      object
# HoursPerWeek             object
# TotalHours               object
# APM                     float64
# SelectByHotkeys         float64
# AssignToHotkeys         float64
# UniqueHotkeys             int64
# MinimapAttacks          float64
# MinimapRightClicks      float64
# NumberOfPACs            float64
# GapBetweenPACs          float64
# ActionLatency           float64
# ActionsInPAC            float64
# TotalMapExplored          int64
# WorkersMade             float64
# UniqueUnitsMade           int64
# ComplexUnitsMade        float64
# ComplexAbilitiesUsed    float64
# dtype: object

# %% [markdown]
# - We see here that some variables are continuous and others are discret. Moreover, Age, HoursPerWeek and TotalHours are objects. It can be a sign of missed values

# %% [markdown]
# ### Quality of values

# %% [markdown]
# - Let's have a look on missed values / NA / 0 etc..

# %%
dataset.isnull().sum()
# Out:
# LeagueIndex             0
# Age                     0
# HoursPerWeek            0
# TotalHours              0
# APM                     0
# SelectByHotkeys         0
# AssignToHotkeys         0
# UniqueHotkeys           0
# MinimapAttacks          0
# MinimapRightClicks      0
# NumberOfPACs            0
# GapBetweenPACs          0
# ActionLatency           0
# ActionsInPAC            0
# TotalMapExplored        0
# WorkersMade             0
# UniqueUnitsMade         0
# ComplexUnitsMade        0
# ComplexAbilitiesUsed    0
# dtype: int64

# %% [markdown]
# - It seems to not have any NAN values. But as said early it seems to have a problem with the variables Age, HoursPerWeek and TotalHours.
# Let's check this.

# %%
dataset[['Age', 'HoursPerWeek', 'TotalHours']]
# Out:
#        Age HoursPerWeek TotalHours
# GameID
# 52      27           10       3000
# 55      23           10       5000
# 56      30           10        200
# 57      19           20        400
# 58      32           10        500
# ...     ..          ...        ...
# 10089    ?            ?          ?
# 10090    ?            ?          ?
# 10092    ?            ?          ?
# 10094    ?            ?          ?
# 10095    ?            ?          ?
#
# [3395 rows x 3 columns]

# %% [markdown]
# - Missed values seems to been encoded with '?'

# %%
missed_value_count = dataset[dataset=='?'].count()
missed_value_count
# Out:
# LeagueIndex              0
# Age                     55
# HoursPerWeek            56
# TotalHours              57
# APM                      0
# SelectByHotkeys          0
# AssignToHotkeys          0
# UniqueHotkeys            0
# MinimapAttacks           0
# MinimapRightClicks       0
# NumberOfPACs             0
# GapBetweenPACs           0
# ActionLatency            0
# ActionsInPAC             0
# TotalMapExplored         0
# WorkersMade              0
# UniqueUnitsMade          0
# ComplexUnitsMade         0
# ComplexAbilitiesUsed     0
# dtype: int64

# %% [markdown]
# - We can replace these values by the mean of the concerned features. Indeed we are in a classification problem and delete these rows could delete a class of our target.

# %%
# Get the concerned columns
columns_to_modify = missed_value_count.index[missed_value_count>0]

# Replace with the mean
for col in columns_to_modify:
    mean = dataset[col][dataset[col] != '?'].astype(int).mean()
    dataset[col].replace("?", int(mean), inplace=True)

# Update columns type
dataset = dataset.astype({'Age':int, 'HoursPerWeek':int, 'TotalHours':int} )

# %% [markdown]
# ### Check if all is good

# %%
dataset[dataset=='?'].count()
# Out:
# LeagueIndex             0
# Age                     0
# HoursPerWeek            0
# TotalHours              0
# APM                     0
# SelectByHotkeys         0
# AssignToHotkeys         0
# UniqueHotkeys           0
# MinimapAttacks          0
# MinimapRightClicks      0
# NumberOfPACs            0
# GapBetweenPACs          0
# ActionLatency           0
# ActionsInPAC            0
# TotalMapExplored        0
# WorkersMade             0
# UniqueUnitsMade         0
# ComplexUnitsMade        0
# ComplexAbilitiesUsed    0
# dtype: int64

# %%
dataset.dtypes
# Out:
# LeagueIndex               int64
# Age                       int32
# HoursPerWeek              int32
# TotalHours                int32
# APM                     float64
# SelectByHotkeys         float64
# AssignToHotkeys         float64
# UniqueHotkeys             int64
# MinimapAttacks          float64
# MinimapRightClicks      float64
# NumberOfPACs            float64
# GapBetweenPACs          float64
# ActionLatency           float64
# ActionsInPAC            float64
# TotalMapExplored          int64
# WorkersMade             float64
# UniqueUnitsMade           int64
# ComplexUnitsMade        float64
# ComplexAbilitiesUsed    float64
# dtype: object

# %% [markdown]
# - Alright ! We are ready to start !

# %% [markdown]
# ### Check the range / mean / std... of each features

# %%
dataset.describe().T
# Out:
#                        count        mean           std        min         25%  \
# LeagueIndex           3395.0    4.184094      1.517327   1.000000    3.000000
# Age                   3395.0   21.637408      4.172921  16.000000   19.000000
# HoursPerWeek          3395.0   15.895729     11.864377   0.000000    8.000000
# TotalHours            3395.0  960.414728  17172.094828   3.000000  300.000000
# APM                   3395.0  117.046947     51.945291  22.059600   79.900200
# SelectByHotkeys       3395.0    0.004299      0.005284   0.000000    0.001258
# AssignToHotkeys       3395.0    0.000374      0.000225   0.000000    0.000204
# UniqueHotkeys         3395.0    4.364654      2.360333   0.000000    3.000000
# MinimapAttacks        3395.0    0.000098      0.000166   0.000000    0.000000
# MinimapRightClicks    3395.0    0.000387      0.000377   0.000000    0.000140
# NumberOfPACs          3395.0    0.003463      0.000992   0.000679    0.002754
# GapBetweenPACs        3395.0   40.361562     17.153570   6.666700   28.957750
# ActionLatency         3395.0   63.739403     19.238869  24.093600   50.446600
# ActionsInPAC          3395.0    5.272988      1.494835   2.038900    4.272850
# TotalMapExplored      3395.0   22.131664      7.431719   5.000000   17.000000
# WorkersMade           3395.0    0.001032      0.000519   0.000077    0.000683
# UniqueUnitsMade       3395.0    6.534021      1.857697   2.000000    5.000000
# ComplexUnitsMade      3395.0    0.000059      0.000111   0.000000    0.000000
# ComplexAbilitiesUsed  3395.0    0.000142      0.000265   0.000000    0.000000
#
#                              50%         75%             max
# LeagueIndex             4.000000    5.000000        8.000000
# Age                    21.000000   24.000000       44.000000
# HoursPerWeek           12.000000   20.000000      168.000000
# TotalHours            500.000000  800.000000  1000000.000000
# APM                   108.010200  142.790400      389.831400
# SelectByHotkeys         0.002500    0.005133        0.043088
# AssignToHotkeys         0.000353    0.000499        0.001752
# UniqueHotkeys           4.000000    6.000000       10.000000
# MinimapAttacks          0.000040    0.000119        0.003019
# MinimapRightClicks      0.000281    0.000514        0.004041
# NumberOfPACs            0.003395    0.004027        0.007971
# GapBetweenPACs         36.723500   48.290500      237.142900
# ActionLatency          60.931800   73.681300      176.372100
# ActionsInPAC            5.095500    6.033600       18.558100
# TotalMapExplored       22.000000   27.000000       58.000000
# WorkersMade             0.000905    0.001259        0.005149
# UniqueUnitsMade         6.000000    8.000000       13.000000
# ComplexUnitsMade        0.000000    0.000086        0.000902
# ComplexAbilitiesUsed    0.000020    0.000181        0.003084

# %% [markdown]
# - We can see that our target LeagueIndex is an int between 1 (beginner) and 8 (professional). Thus a middle player would have a league index of 4.
#     But the most important here is the TotalHours and HoursPerWeek features, a player seems to have passed 1,000,000 hours on the game and another play 24/24! We have to check these features.

# %% [markdown]
# - First, TotalHours :

# %%
dataset.sort_values('TotalHours', ascending=False)
# Out:
#         LeagueIndex  Age  HoursPerWeek  TotalHours       APM  SelectByHotkeys  \
# GameID
# 5140              5   18            24     1000000  281.4246         0.023428
# 6518              6   20             8       25000  247.0164         0.015794
# 2246              5   22            16       20000  248.0490         0.023703
# 5610              4   22            10       18000  152.2374         0.011983
# 6242              3   24            20       10260   76.5852         0.000780
# ...             ...  ...           ...         ...       ...              ...
# 921               4   19             2          10   55.9674         0.000820
# 979               2   16            10          10   32.6730         0.001263
# 4320              2   16            10          10   44.9700         0.001562
# 1207              4   16             2           7  111.3582         0.004802
# 2829              3   16            28           3   69.5748         0.001016
#
#         AssignToHotkeys  UniqueHotkeys  MinimapAttacks  MinimapRightClicks  \
# GameID
# 5140           0.000799              5        0.000041            0.000447
# 6518           0.000438              8        0.000308            0.001339
# 2246           0.000391              7        0.000000            0.000205
# 5610           0.000206              1        0.000016            0.000364
# 6242           0.000197              0        0.000063            0.000316
# ...                 ...            ...             ...                 ...
# 921            0.000315              1        0.000011            0.000045
# 979            0.000111              0        0.000019            0.000056
# 4320           0.000134              4        0.000000            0.000000
# 1207           0.000150              0        0.000060            0.000360
# 2829           0.000371              3        0.000000            0.000239
#
#         NumberOfPACs  GapBetweenPACs  ActionLatency  ActionsInPAC  \
# GameID
# 5140        0.005136         28.1164        36.1266        5.8522
# 6518        0.004645         17.6471        37.1837        6.5944
# 2246        0.004651         37.8795        45.3760        4.7560
# 5610        0.003351         52.1896        63.9811        4.9575
# 6242        0.002438         42.9480        84.6340        5.9107
# ...              ...             ...            ...           ...
# 921         0.003000         64.8271        83.0562        3.3296
# 979         0.001244         95.8788       119.1642        4.1493
# 4320        0.001741        156.6234       110.6154        3.8462
# 1207        0.002551         64.2381        71.8118        6.2000
# 2829        0.003623         57.3775        69.4389        3.3234
#
#         TotalMapExplored  WorkersMade  UniqueUnitsMade  ComplexUnitsMade  \
# GameID
# 5140                  29     0.001328                6          0.000000
# 6518                  29     0.001860                6          0.000000
# 2246                  21     0.001526                6          0.000000
# 5610                  19     0.000680                5          0.000000
# 6242                  27     0.000450               10          0.000246
# ...                  ...          ...              ...               ...
# 921                   15     0.000562                7          0.000000
# 979                   10     0.000854                3          0.000000
# 4320                  18     0.000647                5          0.000000
# 1207                  17     0.001531                4          0.000000
# 2829                  18     0.000550                7          0.000000
#
#         ComplexAbilitiesUsed
# GameID
# 5140                0.000000
# 6518                0.000012
# 2246                0.000000
# 5610                0.000000
# 6242                0.000358
# ...                      ...
# 921                 0.000112
# 979                 0.000000
# 4320                0.000000
# 1207                0.000000
# 2829                0.000490
#
# [3395 rows x 19 columns]

# %% [markdown]
# It seems to be the only weird value for this feature. Indeed 25,000 hours is about 3 years and it is possible for a 20 years old player. So let's remove the player with the 5140 GameID.

# %%
dataset.drop(index=5140, inplace=True)

# %% [markdown]
# - Then, HoursPerWeek :

# %%
dataset.sort_values('HoursPerWeek', ascending=False)
# Out:
#         LeagueIndex  Age  HoursPerWeek  TotalHours       APM  SelectByHotkeys  \
# GameID
# 2000              6   16           168        1260  233.3058         0.017521
# 4817              6   21           140        1800  197.7774         0.006001
# 3733              6   24           112        1500  139.7598         0.005748
# 4754              7   18            98         700  236.0316         0.015664
# 7435              4   34            96         400   56.8584         0.000059
# ...             ...  ...           ...         ...       ...              ...
# 7836              4   21             2         255   84.5652         0.001757
# 6545              5   28             2         200   60.7074         0.001067
# 9141              6   24             2         730  121.4622         0.007075
# 9216              2   30             2         240   54.8400         0.001250
# 2985              6   16             0         365   86.1174         0.000397
#
#         AssignToHotkeys  UniqueHotkeys  MinimapAttacks  MinimapRightClicks  \
# GameID
# 2000           0.000744             10        0.000178            0.000235
# 4817           0.000383              4        0.000308            0.001307
# 3733           0.000368              4        0.000213            0.000155
# 4754           0.001015             10        0.000366            0.001632
# 7435           0.000029              1        0.000029            0.000265
# ...                 ...            ...             ...                 ...
# 7836           0.000286              4        0.000016            0.000556
# 6545           0.000243              6        0.000112            0.000393
# 9141           0.000511              5        0.000000            0.000274
# 9216           0.000360              4        0.000095            0.000455
# 2985           0.000330              3        0.000000            0.000198
#
#         NumberOfPACs  GapBetweenPACs  ActionLatency  ActionsInPAC  \
# GameID
# 2000        0.005137         25.5962        38.9165        5.0961
# 4817        0.004445         29.9962        42.8764        7.0019
# 3733        0.005011         24.6822        41.8956        4.1489
# 4754        0.006487         18.7787        29.9871        4.3371
# 7435        0.001530         47.6078       129.8462        6.9038
# ...              ...             ...            ...           ...
# 7836        0.003424         54.0383        75.8759        4.1551
# 6545        0.002453         72.6462        84.0000        4.1298
# 9141        0.003993         41.1009        55.3790        3.9087
# 9216        0.001970         52.1553        97.3462        5.2981
# 2985        0.002544         54.3158        66.0260        6.1299
#
#         TotalMapExplored  WorkersMade  UniqueUnitsMade  ComplexUnitsMade  \
# GameID
# 2000                  43     0.001027               10          0.000315
# 4817                  32     0.001365               11          0.000058
# 3733                  28     0.000756                5          0.000000
# 4754                  25     0.001507                8          0.000000
# 7435                  11     0.000765                5          0.000000
# ...                  ...          ...              ...               ...
# 7836                  34     0.001087               10          0.000155
# 6545                  20     0.000637                5          0.000000
# 9141                  14     0.000766                6          0.000000
# 9216                  17     0.000473                6          0.000000
# 2985                  11     0.001917                4          0.000000
#
#         ComplexAbilitiesUsed
# GameID
# 2000                0.000502
# 4817                0.000350
# 3733                0.000000
# 4754                0.000000
# 7435                0.000000
# ...                      ...
# 7836                0.000188
# 6545                0.000000
# 9141                0.000036
# 9216                0.000000
# 2985                0.000000
#
# [3394 rows x 19 columns]

# %% [markdown]
# - The second hight value is 140 hours per week which means 4h to sleep and eat. It is crazy but possible... So let's just remove the game with 2000 GameID

# %%
dataset.drop(index=2000, inplace=True)

# %% [markdown]
# ## Overview plots

# %% [markdown]
# ### Histogramm

# %% [markdown]
# - Let's have a look on the distribution of each features

# %%
dataset.hist(bins=100, figsize=(16, 16));

# %% [markdown]
# - It seems to have a lot of player having a level between 1 and 6, then the number drops sharply. When we see these splot it seems important to normalize and centralize the data. Moreover the major part of the features have a normal or poisson distribution (so maybe a log transformation is a good idea for some features). We will it when we will split our data in train and test dataset.
#
#     *Note that if we stil have really height value with a feature we would see it directly because his histogramm would be stock on the left side (like a bar at 0). It is the case for MinimapAttacks but we lack of information about this feature and we don't know if it is normal or not..*

# %% [markdown]
# ### Correlation matrix

# %% [markdown]
# - A good idea now would be to check the correlation between each features.

# %%
plt.figure(figsize=(15,15))
sns.heatmap(dataset.corr(),
            vmin=-1, vmax=1,
            cmap='YlGnBu',
            annot=True, 
            square=True);

# %% [markdown]
# - Here we could expect that Age and the League index are correlated but, it is not the case and it seems to have good player among the young and old ! We see that it is the more technical features which are the most predictive of player's level, like APM which is hight for hight level or Action latency which will be very quick with the best players. We also have GapBetweenPACs, and AssignToHotkeys which are good predictive features.
#
#     So, we progressively dress the typical profil of a good player : low latency, quick reaction, use the hotkeys to select their units (which is also correlated to the reaction) etc...

# %% [markdown]
# ### KDE of interesting features

# %% [markdown]
# - So, let's have a look on some of the features we have seen before

# %%
for k, feature in enumerate(['APM', 'ActionLatency', 'SelectByHotkeys']):
    plt.subplot(2, 2, k+1);
    dataset.groupby('LeagueIndex')[feature].plot.kde(legend=True, 
                                                     figsize=(10, 10),
                                                    xlim=(min(dataset[feature]), 
                                                          max(dataset[feature])),
                                                    ylabel="Density",
                                                    grid=True,
                                                    title=f"{feature} by LeagueIndex");
    plt.xlabel(feature);
plt.show();

# %% [markdown]
# - For the two first plots (APM and League Index) the means for each league index are well separate and comfort the idea that it is good features to predict the player's level. However SelectByHotkeys seems to be a good predictor only for the best player. It means that the player having a score between 0 and 6 don't use hot key but when we have a level at 7 or 8 we must improve all our techniques and use hot keys can be an axe of improvment.

# %% [markdown]
# ### Scatter matrix

# %% [markdown]
# - So let's take som of our previous features, plot them and color the observation with the league index

# %%
interesting_features = ['NumberOfPACs', 'ActionLatency', 'GapBetweenPACs', 'APM']

pd.plotting.scatter_matrix(dataset[interesting_features], 
                           c=dataset['LeagueIndex'],
                           cmap='YlGnBu',
                           figsize=(10, 10),
                           label=dataset['LeagueIndex']);

# %% [markdown]
# It's great ! We see here that the league index evolves progressivly with the value of the feature.

# %% [markdown]
# ## Data Prepocessing

# %% [markdown]
# ### Train and Test set

# %% [markdown]
# - First, let's split the dataset and shuffle it

# %%
X = dataset.drop(['LeagueIndex'], axis=1).to_numpy()
Y = dataset['LeagueIndex'].to_numpy()

X_train, X_test, y_train, y_test = train_test_split(X, Y, 
                                                    random_state=42,
                                                    shuffle=True,
                                                    test_size=0.2)

print('X:', X_train.shape, X_test.shape)
print('Y:', y_train.shape, y_test.shape)
# Out:
# X: (2714, 18) (679, 18)
# Y: (2714,) (679,)

# %%
clf = RandomForestClassifier(n_estimators=1000)

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=1000)

# %%
clf.score(X_test, y_test)
# Out:
# 0.42415316642120765
